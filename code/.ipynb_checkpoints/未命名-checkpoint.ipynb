# %%
from __future__ import print_function
from Evaluate import Evaluate

from keras.layers import *
from keras.models import Model
import keras.backend as K
from keras.optimizers import Adam
from data_loader import DataGenerator
# Out:
# Using TensorFlow backend.
# /Users/zhongkai/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/zhongkai/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/zhongkai/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/zhongkai/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/zhongkai/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/zhongkai/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
class Attention(Layer):
    """多头注意力机制
    """

    def __init__(self, nb_head, size_per_head, **kwargs):
        self.nb_head = nb_head
        self.size_per_head = size_per_head
        self.out_dim = nb_head * size_per_head
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        super(Attention, self).build(input_shape)
        q_in_dim = input_shape[0][-1]
        k_in_dim = input_shape[1][-1]
        v_in_dim = input_shape[2][-1]
        self.q_kernel = self.add_weight(name='q_kernel',
                                        shape=(q_in_dim, self.out_dim),
                                        initializer='glorot_normal')
        self.k_kernel = self.add_weight(name='k_kernel',
                                        shape=(k_in_dim, self.out_dim),
                                        initializer='glorot_normal')
        self.v_kernel = self.add_weight(name='w_kernel',
                                        shape=(v_in_dim, self.out_dim),
                                        initializer='glorot_normal')

    def mask(self, x, mask, mode='mul'):
        if mask is None:
            return x
        else:
            for _ in range(K.ndim(x) - K.ndim(mask)):
                mask = K.expand_dims(mask, K.ndim(mask))
            if mode == 'mul':
                return x * mask
            else:
                return x - (1 - mask) * 1e10

    def call(self, inputs):
        q, k, v = inputs[:3]
        v_mask, q_mask = None, None
        if len(inputs) > 3:
            v_mask = inputs[3]
            if len(inputs) > 4:
                q_mask = inputs[4]
        # 线性变换
        qw = K.dot(q, self.q_kernel)
        kw = K.dot(k, self.k_kernel)
        vw = K.dot(v, self.v_kernel)
        # 形状变换
        qw = K.reshape(
            qw, (-1, K.shape(qw)[1], self.nb_head, self.size_per_head))
        kw = K.reshape(
            kw, (-1, K.shape(kw)[1], self.nb_head, self.size_per_head))
        vw = K.reshape(
            vw, (-1, K.shape(vw)[1], self.nb_head, self.size_per_head))
        # 维度置换
        qw = K.permute_dimensions(qw, (0, 2, 1, 3))
        kw = K.permute_dimensions(kw, (0, 2, 1, 3))
        vw = K.permute_dimensions(vw, (0, 2, 1, 3))
        # Attention
        a = K.batch_dot(qw, kw, [3, 3]) / self.size_per_head ** 0.5
        a = K.permute_dimensions(a, (0, 3, 2, 1))
        a = self.mask(a, v_mask, 'add')
        a = K.permute_dimensions(a, (0, 3, 2, 1))
        a = K.softmax(a)
        # 完成输出
        o = K.batch_dot(a, vw, [3, 2])
        o = K.permute_dimensions(o, (0, 2, 1, 3))
        o = K.reshape(o, (-1, K.shape(o)[1], self.out_dim))
        o = self.mask(o, q_mask, 'mul')
        return o

    def compute_output_shape(self, input_shape):
        return (input_shape[0][0], input_shape[0][1], self.out_dim)

# %%
class PCNN():

    def __init__(self, data_generate):
        self.data_generate = data_generate
        self.build_model()

    def position_id(self, x):
        if isinstance(x, list) and len(x) == 2:
            x, r = x
        else:
            r = 0
        pid = K.arange(K.shape(x)[1])
        pid = K.expand_dims(pid, 0)
        pid = K.tile(pid, [K.shape(x)[0], 1])
        return K.abs(pid - K.cast(r, 'int32'))

    def build_model(self):
        t1_in = Input(shape=(None,))
        t2_in = Input(shape=(None, self.data_generate.data_loader.word_size))
        s1_in = Input(shape=(None,))
        s2_in = Input(shape=(None,))
        k1_in = Input(shape=(1,))
        k2_in = Input(shape=(1,))
        o1_in = Input(shape=(None, self.data_generate.data_loader.num_classes))
        o2_in = Input(shape=(None, self.data_generate.data_loader.num_classes))

        t1, t2, s1, s2, k1, k2, o1, o2 = t1_in, t2_in, s1_in, s2_in, k1_in, k2_in, o1_in, o2_in
        mask = Lambda(lambda x: K.cast(
            K.greater(K.expand_dims(x, 2), 0), 'float32'))(t1)

        pid = Lambda(self.position_id)(t1)
        position_embedding = Embedding(self.data_generate.data_loader.maxlen, self.data_generate.data_loader.char_size,
                                       embeddings_initializer='zeros')
        pv = position_embedding(pid)

        t1 = Embedding(len(self.data_generate.data_loader.char2id) + 2, self.data_generate.data_loader.char_size)(
            t1)  # 0: padding, 1: unk
        t2 = Dense(self.data_generate.data_loader.char_size,
                   use_bias=False)(t2)  # 词向量也转为同样维度
        t = Add()([t1, t2, pv])  # 字向量、词向量、位置向量相加
        t = Dropout(0.25)(t)
        t = Lambda(lambda x: x[0] * x[1])([t, mask])
        t = dilated_gated_conv1d(t, mask, 1)
        t = dilated_gated_conv1d(t, mask, 2)
        t = dilated_gated_conv1d(t, mask, 5)
        t = dilated_gated_conv1d(t, mask, 1)
        t = dilated_gated_conv1d(t, mask, 2)
        t = dilated_gated_conv1d(t, mask, 5)
        t = dilated_gated_conv1d(t, mask, 1)
        t = dilated_gated_conv1d(t, mask, 2)
        t = dilated_gated_conv1d(t, mask, 5)
        t = dilated_gated_conv1d(t, mask, 1)
        t = dilated_gated_conv1d(t, mask, 1)
        t = dilated_gated_conv1d(t, mask, 1)
        t_dim = K.int_shape(t)[-1]

        pn1 = Dense(self.data_generate.data_loader.char_size,
                    activation='relu')(t)
        pn1 = Dense(1, activation='sigmoid')(pn1)
        pn2 = Dense(self.data_generate.data_loader.char_size,
                    activation='relu')(t)
        pn2 = Dense(1, activation='sigmoid')(pn2)

        h = Attention(8, 16)([t, t, t, mask])
        h = Concatenate()([t, h])
        h = Conv1D(self.data_generate.data_loader.char_size,
                   3, activation='relu', padding='same')(h)
        ps1 = Dense(1, activation='sigmoid')(h)
        ps2 = Dense(1, activation='sigmoid')(h)
        ps1 = Lambda(lambda x: x[0] * x[1])([ps1, pn1])
        ps2 = Lambda(lambda x: x[0] * x[1])([ps2, pn2])

        subject_model = Model([t1_in, t2_in], [ps1, ps2])  # 预测subject的模型

        t_max = Lambda(seq_maxpool)([t, mask])
        pc = Dense(self.data_generate.data_loader.char_size,
                   activation='relu')(t_max)
        pc = Dense(self.data_generate.data_loader.num_classes,
                   activation='sigmoid')(pc)

        k = Lambda(self.get_k_inter, output_shape=(6, t_dim))([t, k1, k2])
#         k = Bidirectional(CuDNNGRU(t_dim))(k)
        k = Bidirectional(GRU(t_dim))(k)
        k1v = position_embedding(Lambda(self.position_id)([t, k1]))
        k2v = position_embedding(Lambda(self.position_id)([t, k2]))
        kv = Concatenate()([k1v, k2v])
        k = Lambda(lambda x: K.expand_dims(x[0], 1) + x[1])([k, kv])

        h = Attention(8, 16)([t, t, t, mask])
        h = Concatenate()([t, h, k])
        h = Conv1D(self.data_generate.data_loader.char_size,
                   3, activation='relu', padding='same')(h)
        po = Dense(1, activation='sigmoid')(h)
        po1 = Dense(self.data_generate.data_loader.num_classes,
                    activation='sigmoid')(h)
        po2 = Dense(self.data_generate.data_loader.num_classes,
                    activation='sigmoid')(h)

        po1 = Lambda(lambda x: x[0] * x[1] * x[2] * x[3])([po, po1, pc, pn1])
        po2 = Lambda(lambda x: x[0] * x[1] * x[2] * x[3])([po, po2, pc, pn2])

        object_model = Model([t1_in, t2_in, k1_in, k2_in], [
                             po1, po2])  # 输入text和subject，预测object及其关系

        train_model = Model([t1_in, t2_in, s1_in, s2_in, k1_in, k2_in, o1_in, o2_in],
                            [ps1, ps2, po1, po2])

        s1 = K.expand_dims(s1, 2)
        s2 = K.expand_dims(s2, 2)

        s1_loss = K.binary_crossentropy(s1, ps1)
        s1_loss = K.sum(s1_loss * mask) / K.sum(mask)
        s2_loss = K.binary_crossentropy(s2, ps2)
        s2_loss = K.sum(s2_loss * mask) / K.sum(mask)

        o1_loss = K.sum(K.binary_crossentropy(o1, po1), 2, keepdims=True)
        o1_loss = K.sum(o1_loss * mask) / K.sum(mask)
        o2_loss = K.sum(K.binary_crossentropy(o2, po2), 2, keepdims=True)
        o2_loss = K.sum(o2_loss * mask) / K.sum(mask)

        loss = (s1_loss + s2_loss) + (o1_loss + o2_loss)
        train_model.add_loss(loss)

        # train_model.compile(optimizer=Adam(lr=1e-3))
        train_model.compile(optimizer=Adam(lr=1e-5))
        train_model.summary()
        self.train_model = train_model
        self.subject_model = subject_model
        self.object_model = object_model

    def position_id(self, x):
        if isinstance(x, list) and len(x) == 2:
            x, r = x
        else:
            r = 0
        pid = K.arange(K.shape(x)[1])
        pid = K.expand_dims(pid, 0)
        pid = K.tile(pid, [K.shape(x)[0], 1])
        return K.abs(pid - K.cast(r, 'int32'))

    def get_k_inter(self, x, n=6):
        seq, k1, k2 = x
        k_inter = [K.round(k1 * a + k2 * (1 - a))
                   for a in np.arange(n) / (n - 1.)]
        k_inter = [seq_gather([seq, k]) for k in k_inter]
        k_inter = [K.expand_dims(k, 1) for k in k_inter]
        k_inter = K.concatenate(k_inter, 1)
        return k_inter

    def train(self, data=None):
        EMAer = ExponentialMovingAverage(self.train_model)
        EMAer.inject()
        if data == None:
            data = self.data_generate
#         self.train_model.load_weights('best_train_model.weights')
        # self.subject_model.load_weights("best_subject_model.weights")
        # self.object_model.load_weights("best_object_model.weights")
        evaluator = Evaluate(
            self.train_model, self.subject_model, self.object_model, EMAer)
        # reduce_lr = ReduceLROnPlateau(monitor='loss', patience=1, mode='auto')
        self.train_model.fit_generator(data.__iter__(),
                                       steps_per_epoch=len(data),
                                       epochs=60,
                                       callbacks=[evaluator]
                                       )

# %%
class ExponentialMovingAverage:
    """对模型权重进行指数滑动平均。
    用法：在model.compile之后、第一次训练之前使用；
    先初始化对象，然后执行inject方法。
    """

    def __init__(self, model, momentum=0.9999):
        self.momentum = momentum
        self.model = model
        self.ema_weights = [K.zeros(K.shape(w)) for w in model.weights]

    def inject(self):
        """添加更新算子到model.metrics_updates。
        """
        self.initialize()
        for w1, w2 in zip(self.ema_weights, self.model.weights):
            op = K.moving_average_update(w1, w2, self.momentum)
            self.model.metrics_updates.append(op)

    def initialize(self):
        """ema_weights初始化跟原模型初始化一致。
        """
        self.old_weights = K.batch_get_value(self.model.weights)
        K.batch_set_value(zip(self.ema_weights, self.old_weights))

    def apply_ema_weights(self):
        """备份原模型权重，然后将平均权重应用到模型上去。
        """
        self.old_weights = K.batch_get_value(self.model.weights)
        ema_weights = K.batch_get_value(self.ema_weights)
        K.batch_set_value(zip(self.model.weights, ema_weights))

    def reset_old_weights(self):
        """恢复模型到旧权重。
        """
        K.batch_set_value(zip(self.model.weights, self.old_weights))

# %%
def seq_gather(x):
    """seq是[None, seq_len, s_size]的格式，
    idxs是[None, 1]的格式，在seq的第i个序列中选出第idxs[i]个向量，
    最终输出[None, s_size]的向量。
    """
    seq, idxs = x
    idxs = K.cast(idxs, 'int32')
    batch_idxs = K.arange(0, K.shape(seq)[0])
    batch_idxs = K.expand_dims(batch_idxs, 1)
    idxs = K.concatenate([batch_idxs, idxs], 1)
    return K.tf.gather_nd(seq, idxs)


def seq_maxpool(x):
    """seq是[None, seq_len, s_size]的格式，
    mask是[None, seq_len, 1]的格式，先除去mask部分，
    然后再做maxpooling。
    """
    seq, mask = x
    seq -= (1 - mask) * 1e10
    return K.max(seq, 1, keepdims=True)


def dilated_gated_conv1d(seq, mask, dilation_rate=1):
    """膨胀门卷积（残差式）
    """
    dim = K.int_shape(seq)[-1]
    h = Conv1D(dim * 2, 3, padding='same', dilation_rate=dilation_rate)(seq)

    def _gate(x):
        dropout_rate = 0.1
        s, h = x
        g, h = h[:, :, :dim], h[:, :, dim:]
        g = K.in_train_phase(K.dropout(g, dropout_rate), g)
        g = K.sigmoid(g)
        return g * s + (1 - g) * h

    seq = Lambda(_gate)([seq, h])
    seq = Lambda(lambda x: x[0] * x[1])([seq, mask])
    return seq

# %%
data_generate = DataGenerator(train=True, batch_size=64)

# %%
pcnn_model = PCNN(data_generate)
# Out:
# WARNING:tensorflow:From /Users/zhongkai/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/control_flow_ops.py:423: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/zhongkai/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 256)    0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, None)         0           input_1[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, None, 128)    899840      input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 128)    32768       input_2[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    65536       lambda_2[0][0]
#                                                                  lambda_32[0][0]
#                                                                  lambda_33[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, 128)    0           embedding_2[0][0]
#                                                                  dense_1[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, 128)    0           add_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, 1)      0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, None, 128)    0           dropout_1[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, None, 256)    98560       lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, None, 128)    0           lambda_3[0][0]
#                                                                  conv1d_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, None, 128)    0           lambda_4[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, None, 256)    98560       lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, None, 128)    0           lambda_5[0][0]
#                                                                  conv1d_2[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, None, 128)    0           lambda_6[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, None, 256)    98560       lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, None, 128)    0           lambda_7[0][0]
#                                                                  conv1d_3[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, None, 128)    0           lambda_8[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, None, 256)    98560       lambda_9[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, None, 128)    0           lambda_9[0][0]
#                                                                  conv1d_4[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, None, 128)    0           lambda_10[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, None, 256)    98560       lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, None, 128)    0           lambda_11[0][0]
#                                                                  conv1d_5[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, None, 128)    0           lambda_12[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, None, 256)    98560       lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, None, 128)    0           lambda_13[0][0]
#                                                                  conv1d_6[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, None, 128)    0           lambda_14[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, None, 256)    98560       lambda_15[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, None, 128)    0           lambda_15[0][0]
#                                                                  conv1d_7[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, None, 128)    0           lambda_16[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, None, 256)    98560       lambda_17[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, None, 128)    0           lambda_17[0][0]
#                                                                  conv1d_8[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, None, 128)    0           lambda_18[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, None, 256)    98560       lambda_19[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, None, 128)    0           lambda_19[0][0]
#                                                                  conv1d_9[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, None, 128)    0           lambda_20[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, None, 256)    98560       lambda_21[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, None, 128)    0           lambda_21[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, None, 128)    0           lambda_22[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, None, 256)    98560       lambda_23[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, None, 128)    0           lambda_23[0][0]
#                                                                  conv1d_11[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, None, 128)    0           lambda_24[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, None, 256)    98560       lambda_25[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, None, 128)    0           lambda_25[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, None, 128)    0           lambda_26[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, None)         0           lambda_27[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, None)         0           lambda_27[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 6, 128)       0           lambda_27[0][0]
#                                                                  input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 256)          197376      lambda_31[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, 256)    0           embedding_1[1][0]
#                                                                  embedding_1[2][0]
# __________________________________________________________________________________________________
# attention_1 (Attention)         (None, None, 128)    49152       lambda_27[0][0]
#                                                                  lambda_27[0][0]
#                                                                  lambda_27[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# attention_2 (Attention)         (None, None, 128)    49152       lambda_27[0][0]
#                                                                  lambda_27[0][0]
#                                                                  lambda_27[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, None, 256)    0           bidirectional_1[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, 256)    0           lambda_27[0][0]
#                                                                  attention_1[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, 512)    0           lambda_27[0][0]
#                                                                  attention_2[0][0]
#                                                                  lambda_34[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 1, 128)       0           lambda_27[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, None, 128)    98432       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, None, 128)    16512       lambda_27[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, None, 128)    16512       lambda_27[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, None, 128)    196736      concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1, 128)       16512       lambda_30[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, None, 1)      129         conv1d_13[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, None, 1)      129         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, None, 1)      129         conv1d_13[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, None, 1)      129         dense_4[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, None, 1)      129         conv1d_14[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, None, 49)     6321        conv1d_14[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 49)        6321        dense_8[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, None, 49)     6321        conv1d_14[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, None, 1)      0           dense_6[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, None, 1)      0           dense_7[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, None, 49)     0           dense_10[0][0]
#                                                                  dense_11[0][0]
#                                                                  dense_9[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, None, 49)     0           dense_10[0][0]
#                                                                  dense_12[0][0]
#                                                                  dense_9[0][0]
#                                                                  dense_5[0][0]
# ==================================================================================================
# Total params: 2,840,856
# Trainable params: 2,840,856
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
pcnn_model.build_model()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           (None, None, 256)    0
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, None)         0           input_9[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, None, 128)    899840      input_9[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, None, 128)    32768       input_10[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, None, 128)    65536       lambda_38[0][0]
#                                                                  lambda_68[0][0]
#                                                                  lambda_69[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, 128)    0           embedding_4[0][0]
#                                                                  dense_13[0][0]
#                                                                  embedding_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, None, 128)    0           add_2[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, None, 1)      0           input_9[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, None, 128)    0           dropout_2[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, None, 256)    98560       lambda_39[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, None, 128)    0           lambda_39[0][0]
#                                                                  conv1d_15[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, None, 128)    0           lambda_40[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, None, 256)    98560       lambda_41[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, None, 128)    0           lambda_41[0][0]
#                                                                  conv1d_16[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, None, 128)    0           lambda_42[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, None, 256)    98560       lambda_43[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, None, 128)    0           lambda_43[0][0]
#                                                                  conv1d_17[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, None, 128)    0           lambda_44[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, None, 256)    98560       lambda_45[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, None, 128)    0           lambda_45[0][0]
#                                                                  conv1d_18[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, None, 128)    0           lambda_46[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, None, 256)    98560       lambda_47[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, None, 128)    0           lambda_47[0][0]
#                                                                  conv1d_19[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, None, 128)    0           lambda_48[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, None, 256)    98560       lambda_49[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, None, 128)    0           lambda_49[0][0]
#                                                                  conv1d_20[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, None, 128)    0           lambda_50[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, None, 256)    98560       lambda_51[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, None, 128)    0           lambda_51[0][0]
#                                                                  conv1d_21[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, None, 128)    0           lambda_52[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, None, 256)    98560       lambda_53[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, None, 128)    0           lambda_53[0][0]
#                                                                  conv1d_22[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, None, 128)    0           lambda_54[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, None, 256)    98560       lambda_55[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, None, 128)    0           lambda_55[0][0]
#                                                                  conv1d_23[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, None, 128)    0           lambda_56[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, None, 256)    98560       lambda_57[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, None, 128)    0           lambda_57[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, None, 128)    0           lambda_58[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, None, 256)    98560       lambda_59[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, None, 128)    0           lambda_59[0][0]
#                                                                  conv1d_25[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, None, 128)    0           lambda_60[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, None, 256)    98560       lambda_61[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, None, 128)    0           lambda_61[0][0]
#                                                                  conv1d_26[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, None, 128)    0           lambda_62[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# input_13 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, None)         0           lambda_63[0][0]
#                                                                  input_13[0][0]
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, None)         0           lambda_63[0][0]
#                                                                  input_14[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 6, 128)       0           lambda_63[0][0]
#                                                                  input_13[0][0]
#                                                                  input_14[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 256)          197376      lambda_67[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, None, 256)    0           embedding_3[1][0]
#                                                                  embedding_3[2][0]
# __________________________________________________________________________________________________
# attention_3 (Attention)         (None, None, 128)    49152       lambda_63[0][0]
#                                                                  lambda_63[0][0]
#                                                                  lambda_63[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# attention_4 (Attention)         (None, None, 128)    49152       lambda_63[0][0]
#                                                                  lambda_63[0][0]
#                                                                  lambda_63[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# lambda_70 (Lambda)              (None, None, 256)    0           bidirectional_2[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, None, 256)    0           lambda_63[0][0]
#                                                                  attention_3[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, None, 512)    0           lambda_63[0][0]
#                                                                  attention_4[0][0]
#                                                                  lambda_70[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 1, 128)       0           lambda_63[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, None, 128)    98432       concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, None, 128)    16512       lambda_63[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, None, 128)    16512       lambda_63[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, None, 128)    196736      concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1, 128)       16512       lambda_66[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, None, 1)      129         conv1d_27[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, None, 1)      129         dense_14[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, None, 1)      129         conv1d_27[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, None, 1)      129         dense_16[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, None, 1)      129         conv1d_28[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, None, 49)     6321        conv1d_28[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 1, 49)        6321        dense_20[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, None, 49)     6321        conv1d_28[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, None, 1)      0           dense_18[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, None, 1)      0           dense_19[0][0]
#                                                                  dense_17[0][0]
# __________________________________________________________________________________________________
# lambda_71 (Lambda)              (None, None, 49)     0           dense_22[0][0]
#                                                                  dense_23[0][0]
#                                                                  dense_21[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, None, 49)     0           dense_22[0][0]
#                                                                  dense_24[0][0]
#                                                                  dense_21[0][0]
#                                                                  dense_17[0][0]
# ==================================================================================================
# Total params: 2,840,856
# Trainable params: 2,840,856
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
pcnn_model.train()
# Out:
# WARNING:tensorflow:From /Users/zhongkai/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /Users/zhongkai/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/60
#  104/2367 [>.............................] - ETA: 1:16:21 - loss: 6.5095
